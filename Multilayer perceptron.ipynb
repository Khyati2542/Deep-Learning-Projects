# %%
 
# importing modules 
import tensorflow as tf 
import numpy as np 
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Flatten 
from tensorflow.keras.layers import Dense 
from tensorflow.keras.layers import Activation 
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
# Cast the records into float values 
x_train = x_train.astype('float32') 
x_test = x_test.astype('float32') 
  
# normalize image pixel values by dividing  
# by 255 
gray_scale = 255
x_train /= gray_scale 
x_test /= gray_scale

# %%
 
print("Feature matrix:", x_train.shape) 
print("Target matrix:", x_test.shape) 
print("Feature matrix:", y_train.shape) 
print("Target matrix:", y_test.shape)
# Out:
# Feature matrix: (60000, 28, 28)
# Target matrix: (10000, 28, 28)
# Feature matrix: (60000,)
# Target matrix: (10000,)

# %%
 
fig, ax = plt.subplots(10, 10) 
k = 0
for i in range(10): 
    for j in range(10): 
        ax[i][j].imshow(x_train[k].reshape(28, 28),  
                        aspect='auto') 
        k += 1
plt.show()

# %%
 
model = Sequential([ 
    
    # reshape 28 row * 28 column data to 28*28 rows 
    Flatten(input_shape=(28, 28)), 
    
      # dense layer 1 
    Dense(256, activation='sigmoid'),   
    
    # dense layer 2 
    Dense(128, activation='sigmoid'),  
    
      # output layer 
    Dense(10, activation='sigmoid'),   
])
# Out:
# C:\Users\khyat\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# %%
 
model.fit(x_train, y_train, epochs=10,  
          batch_size=2000,  
          validation_split=0.2)
# Out:
# Epoch 1/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.2655 - loss: 2.2423 - val_accuracy: 0.6633 - val_loss: 1.7520
# Epoch 2/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.6959 - loss: 1.5771 - val_accuracy: 0.8016 - val_loss: 1.0472
# Epoch 3/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.7949 - loss: 0.9602 - val_accuracy: 0.8573 - val_loss: 0.6709
# Epoch 4/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8507 - loss: 0.6487 - val_accuracy: 0.8855 - val_loss: 0.4988
# Epoch 5/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8805 - loss: 0.4918 - val_accuracy: 0.8987 - val_loss: 0.4102
# Epoch 6/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8957 - loss: 0.4133 - val_accuracy: 0.9065 - val_loss: 0.3581
# Epoch 7/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9038 - loss: 0.3658 - val_accuracy: 0.9118 - val_loss: 0.3232
# Epoch 8/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9103 - loss: 0.3338 - val_accuracy: 0.9181 - val_loss: 0.2973
# Epoch 9/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9166 - loss: 0.3040 - val_accuracy: 0.9222 - val_loss: 0.2787
# Epoch 10/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9214 - loss: 0.2856 - val_accuracy: 0.9266 - val_loss: 0.2625

# %%
results = model.evaluate(x_test, y_test, verbose = 0) 
print('test loss, test acc:', results)
# Out:
# test loss, test acc: [0.26668116450309753, 0.9233999848365784]

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Cast the records into float values
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize image pixel values by dividing by 255
gray_scale = 255
x_train /= gray_scale
x_test /= gray_scale

# Print shape information
print("Feature matrix (Training):", x_train.shape)
print("Target matrix (Training):", y_train.shape)
print("Feature matrix (Testing):", x_test.shape)
print("Target matrix (Testing):", y_test.shape)

# Visualize some sample images from the dataset
fig, ax = plt.subplots(10, 10)
k = 0
for i in range(10):
    for j in range(10):
        ax[i][j].imshow(x_train[k].reshape(28, 28), aspect='auto', cmap='gray')
        k += 1
plt.show()

# Build the model
model = Sequential([
    Flatten(input_shape=(28, 28)),  # Reshape 28x28 data to a flat vector
    Dense(256, activation='sigmoid'),  # Dense layer 1
    Dense(128, activation='sigmoid'),  # Dense layer 2
    Dense(10, activation='softmax')    # Output layer
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=10,
                    batch_size=2000,
                    validation_split=0.2)

# Plot training history (accuracy and loss)
plt.figure(figsize=(12, 5))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()

# Evaluate the model on test data
results = model.evaluate(x_test, y_test, verbose=0)
print('Test loss, Test accuracy:', results)
# Out:
# Feature matrix (Training): (60000, 28, 28)
# Target matrix (Training): (60000,)
# Feature matrix (Testing): (10000, 28, 28)
# Target matrix (Testing): (10000,)
# Epoch 1/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.2715 - loss: 2.2206 - val_accuracy: 0.6574 - val_loss: 1.6877
# Epoch 2/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7009 - loss: 1.5123 - val_accuracy: 0.8089 - val_loss: 0.9922
# Epoch 3/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8077 - loss: 0.9166 - val_accuracy: 0.8618 - val_loss: 0.6503
# Epoch 4/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8559 - loss: 0.6292 - val_accuracy: 0.8878 - val_loss: 0.4860
# Epoch 5/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8815 - loss: 0.4917 - val_accuracy: 0.9005 - val_loss: 0.3977
# Epoch 6/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8955 - loss: 0.4072 - val_accuracy: 0.9102 - val_loss: 0.3461
# Epoch 7/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9077 - loss: 0.3550 - val_accuracy: 0.9167 - val_loss: 0.3132
# Epoch 8/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9129 - loss: 0.3231 - val_accuracy: 0.9214 - val_loss: 0.2905
# Epoch 9/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9168 - loss: 0.3015 - val_accuracy: 0.9243 - val_loss: 0.2730
# Epoch 10/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9217 - loss: 0.2772 - val_accuracy: 0.9279 - val_loss: 0.2579
# Test loss, Test accuracy: [0.2646495997905731, 0.9258000254631042]
